# %%
# %matplotlib inline
import matplotlib.pyplot as plt

# %%
time = [0, 1, 2, 3]
position = [0, 100, 200, 300]

plt.plot(time, position)
plt.xlabel('Time (hr)');
plt.ylabel('Position (km)');

# %%
import pandas as pd

data = pd.read_csv('python-novice-gapminder/data/gapminder_gdp_oceania.csv', index_col='country')
